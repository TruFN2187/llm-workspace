# %% [markdown]
# ## Component-lab description
# This notebook will most likely not be as 'detailed' as the 'playground may be but is intended to be used to clean up and finalize 'components' that are in route to being added to the 'final product'
